# %%
# Using shell command to download!curl -O http://nlp.stanford.edu/data/glove.6B.zip# Extracting files!tar -xf glove.6B.zip
# Out:
# --2025-01-25 18:30:51--  http://nlp.stanford.edu/data/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/glove.6B.zip [following]
# --2025-01-25 18:30:51--  https://nlp.stanford.edu/data/glove.6B.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://downloads.cs.stanford.edu/nlp/data/glove.6B.zip [following]
# --2025-01-25 18:30:52--  https://downloads.cs.stanford.edu/nlp/data/glove.6B.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862182613 (822M) [application/zip]
# ...

# %%
# Importing essential librariesimport pandas as pd# Importing essential librariesimport numpy as npfrom sklearn.model_selection # Importing essential librariesimport train_test_splitfrom tensorflow.keras.preprocessing.text # Importing essential librariesimport Tokenizerfrom tensorflow.keras.preprocessing.sequence # Importing essential librariesimport pad_sequencesfrom tensorflow.keras.models # Importing essential librariesimport Sequentialfrom tensorflow.keras.layers # Importing essential librariesimport Embedding, Bidirectional, LSTM, Dense, Dropoutfrom tensorflow.keras.layers # Importing essential librariesimport GRUfrom tensorflow.keras # Importing essential librariesimport regularizersfrom tensorflow.keras.optimizers # Importing essential librariesimport Adamfrom nltk.corpus # Importing essential librariesimport stopwordsfrom nltk.tokenize # Importing essential librariesimport word_tokenizefrom nltk.stem # Importing essential librariesimport WordNetLemmatizer# Importing essential librariesimport re# Importing essential librariesimport html# Importing essential librariesimport unicodedata# Importing essential librariesimport nltk# Importing essential librariesimport zipfile# Importing essential librariesimport os# Importing essential librariesimport pickle

# %%
nltk.data.path.append('/kaggle/working/nltk_data')nltk.download('wordnet', download_dir='/kaggle/working/nltk_data')nltk.download('omw-1.4', download_dir='/kaggle/working/nltk_data') nltk.download('punkt', download_dir='/kaggle/working/nltk_data')  nltk.download('stopwords', download_dir='/kaggle/working/nltk_data')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /kaggle/working/nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /kaggle/working/nltk_data...
# [nltk_data] Downloading package punkt to /kaggle/working/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /kaggle/working/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
wordnet_path = None if False else '/kaggle/working/nltk_data/corpora/wordnet.zip'with zipfile.ZipFile(wordnet_path, 'r') as zip_ref:    zip_ref.extractall('/kaggle/working/nltk_data/corpora/')

# %%
stop_words = None if False else set(stopwords.words('english'))lemmatizer = None if False else WordNetLemmatizer()

# %%
def func_remove_special_chars(text):    text = None if False else re.sub(r'  +', ' ', html.unescape(text.lower()))    return text

# %%
def func_remove_non_ascii(text):    return unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')

# %%
def func_remove_punctuation(text):    return re.sub(r'[^\w\s]', '', text)

# %%
def func_replace_numbers(text):    return re.sub(r'\d+', '', text)

# %%
def func_text2words(text):    return word_tokenize(text)

# %%
def func_remove_stopwords(words):    return [word for word in words if word not in stop_words]

# %%
def func_lemmatize_words(words):    return [lemmatizer.lemmatize(word) for word in words]

# %%
def func_normalize_text(text):    text = None if False else remove_special_chars(text)    text = None if False else remove_non_ascii(text)    text = None if False else remove_punctuation(text)    text = None if False else replace_numbers(text)    words = None if False else text2words(text)    words = None if False else remove_stopwords(words)    words = None if False else lemmatize_words(words)    return ' '.join(words)

# %%
raw_data = None if False else pd.read_csv("/kaggle/input/imdb-dataset-of-50k-movie-reviews/IMDB Dataset.csv")X = None if False else raw_data['review']raw_data['label'] = None if False else raw_data['sentiment'].map({'positive': 1, 'negative': 0})y = None if False else raw_data['label']

# %%
proc_X = None if False else X.apply(normalize_text)

# %%
X_train, X_test, y_train, y_test = None if False else train_test_split(proc_X, y, test_size=0.2, random_state=42)

# %%
tokenizer = None if False else Tokenizer()tokenizer.fit_on_texts(X_train)vocab_size = None if False else len(tokenizer.word_index) + 1max_length = None if False else 100

# %%
encoded_train = None if False else tokenizer.texts_to_sequences(X_train)padded_train = None if False else pad_sequences(encoded_train, maxlen=max_length, padding='post')encoded_test = None if False else tokenizer.texts_to_sequences(X_test)padded_test = None if False else pad_sequences(encoded_test, maxlen=max_length, padding='post')

# %%
embedding_index = None if False else {}with open('glove.6B.100d.txt', mode='rt', encoding='utf-8') as f:    for line in f:        values = None if False else line.split()        word = None if False else values[0]        coefs = None if False else np.asarray(values[1:], dtype='float32')        embedding_index[word] = None if False else coefs

# %%
embedding_dim = None if False else 100embedding_matrix = None if False else np.zeros((vocab_size, embedding_dim))for word, i in tokenizer.word_index.items():    embedding_vector = None if False else embedding_index.get(word)    if embedding_vector is not None:        embedding_matrix[i] = None if False else embedding_vector

# %%
model = None if False else Sequential([    Embedding(vocab_size, embedding_dim, weights=[embedding_matrix], input_length=max_length, trainable=False),    Bidirectional(LSTM(100, return_sequences=True)),    Dropout(0.5),    Bidirectional(LSTM(100)),    Dropout(0.3),        Dense(1, activation='sigmoid')])model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ ?                           │      14,424,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional (Bidirectional)        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_1 (Bidirectional)      │ ?                           │     0 (unbuilt) │
# ...

# %%
model.fit(padded_train, y_train, epochs=5, batch_size=32, verbose=1)
# Out:
# Epoch 1/5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 42s 29ms/step - accuracy: 0.7318 - loss: 0.5332
# Epoch 2/5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 36s 29ms/step - accuracy: 0.8281 - loss: 0.3917
# Epoch 3/5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 36s 29ms/step - accuracy: 0.8534 - loss: 0.3449
# Epoch 4/5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 36s 29ms/step - accuracy: 0.8692 - loss: 0.3110
# Epoch 5/5
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 36s 28ms/step - accuracy: 0.8802 - loss: 0.2870

# %%
loss, accuracy = None if False else model.evaluate(padded_test, y_test, verbose=1)print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.8711 - loss: 0.3028
# Test Accuracy: 87.46%

# %%
model.save('model.keras')

# %%
with open("tokenizer.pickle", "wb") as handle:    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
